# %%
using CSV
using DataFrames
using PairPlots
using CairoMakie

# %%
df = DataFrame(CSV.File("churn.csv"))
# Out:
# 3333×21 DataFrame
#   Row │ State    Account Length  Area Code  Phone     Int'l Plan  VMail Plan   ⋯
#       │ String3  Int64           Int64      String15  String3     String3      ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ KS                  128        415  382-4657  no          yes          ⋯
#     2 │ OH                  107        415  371-7191  no          yes
#     3 │ NJ                  137        415  358-1921  no          no
#     4 │ OH                   84        408  375-9999  yes         no
#     5 │ OK                   75        415  330-6626  yes         no           ⋯
#     6 │ AL                  118        510  391-8027  yes         no
#     7 │ MA                  121        510  355-9993  no          yes
#     8 │ MO                  147        415  329-9001  yes         no
#     9 │ LA                  117        408  335-4719  no          no           ⋯
# ...

# %%
fig = pairplot(select!(df, [:"Day Mins", :"Day Calls"]))
# Out:
# Figure()

# %%
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}
