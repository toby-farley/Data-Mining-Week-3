# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("churn.csv")

plt.figure(figsize=(8,6))
sns.histplot(df["Day Mins"], bins=20, kde=True)
plt.title("Histograpm of Day Minutes")
plt.xlabel("Day Minutes")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(x=df["Day Mins"], y=df["Day Charge"], hue=df["Churn?"])
plt.title("Scatter plot of day charge")
plt.xlabel("Day Minutes")
plt.ylabel("Day Charge")
plt.show()

cross_tab=pd.crosstab(df[r"Int'l Plan"], df["Churn?"])
print(cross_tab)
# Out:
# Churn?      False.  True.
# Int'l Plan
# no            2664    346
# yes            186    137

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df,x_vars=["Day Calls"],y_vars=["Day Mins"])
plt.title("Pair Plot of Calls Per Day and Minutes Per Day")
plt.xlabel("Calls Per Day")
plt.ylabel("Minutes Per Day")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.violinplot(data=df, x="Night Mins", y="Churn?")
plt.title("Violin Plot of Night Mins vs Churn")
plt.xlabel("Night Minutes")
plt.ylabel("Churn")
plt.show()

# %%
#Could not really see that the data has missing values so to do a heatmap, I picked a different set of data.
plt.figure(figsize=(6,20))
sumed = df.groupby(['Churn?','State'], sort=True)["Intl Calls"].mean("Intl Calls")
unstacked = sumed.unstack(level=0)
sns.heatmap(unstacked, annot=True, fmt=".1f")
plt.title("Heatmap of Average of Calls per Account by State and Churn(True/False)")
plt.xlabel("Chrun")
plt.ylabel("State")
plt.show()

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(df, x="Int'l Plan")
plt.xlabel("Has International Plan")
#I added labels because of the large difference and the scale of the x axis
ax.bar_label(ax.containers[0])
plt.show()
